# %% [markdown]
# # 분석환경 설정
# ## 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/정보통계종합설계_플렉스/정보통계종합설계_플렉스
# Out:
# /content/drive/MyDrive/정보통계종합설계_플렉스/정보통계종합설계_플렉스

# %% [markdown]
# # 라이브러리 설정

# %%
import pandas as pd

# %% [markdown]
# # 1. 데이터 불러오기

# %%
data1 = pd.read_csv('datasets/블록별 성별연령대별 카드소비패턴.csv', encoding = 'cp949')
data2 = pd.read_csv('datasets/블록별 시간대별소액결제건수 카드소비패턴.csv', encoding = 'cp949')
data3 = pd.read_csv('datasets/집계구별 일별소비지역별 카드소비패턴.csv', encoding = 'cp949')
data4 = pd.read_csv('datasets/집계구별 일별시간대별 카드소비패턴.csv', encoding = 'cp949')
data5 = pd.read_csv('datasets/카드소비 업종코드.csv', encoding = 'cp949')

# %%
data1
# Out:
#     서울시민업종코드(UPJONG_CD)  기준년월(YM)  고객주소블록코드(BLOCK_CD) 성별(GEDNER) 연령대별(AGE)  \
# 0                 SS013    201906               14037          F       50대
# 1                 SS048    201608              156830          M       30대
# 2                 SS016    202009               32925          M       50대
# 3                 SS001    201805              214245          F       30대
# 4                 SS044    201705              279472          M       30대
# ..                  ...       ...                 ...        ...       ...
# 495               SS012    201709               11449          F       30대
# 496               SS044    201707              353037          F       30대
# 497               SS054    201901              418149          F       20대
# 498               SS021    202009              269015          F     70대이상
# 499               SS003    201812               28101          M       40대
#
#      카드이용금액계(AMT_CORR)  카드이용건수계(USECT_CORR)
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   서울시민업종코드(UPJONG_CD)  500 non-null    object
#  1   기준년월(YM)             500 non-null    int64
#  2   고객주소블록코드(BLOCK_CD)   500 non-null    int64
#  3   성별(GEDNER)           500 non-null    object
#  4   연령대별(AGE)            500 non-null    object
#  5   카드이용금액계(AMT_CORR)    500 non-null    int64
#  6   카드이용건수계(USECT_CORR)  500 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 27.5+ KB

# %%
data2
# Out:
#     서울시민업종코드(UPJONG_CD)  기준년월(YM)  시간대구간(TIME)  고객주소블록코드(BLOCK_CD)  \
# 0                 SS017    202006            6               11063
# 1                 SS013    201608            6              216137
# 2                 SS016    201802            3              224819
# 3                 SS055    201906            2               19869
# 4                 SS038    201612            5               28382
# ..                  ...       ...          ...                 ...
# 495               SS017    201911            5              366735
# 496               SS016    201803            2              155750
# 497               SS081    202103            3              366426
# 498               SS069    201707            3              214935
# 499               SS069    201909            4              225316
#
#      카드이용금액계(AMT_CORR)  소액결제건수(MICRO_PYM)
# 0                  257                 25
# 1                   86                 10
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   서울시민업종코드(UPJONG_CD)  500 non-null    object
#  1   기준년월(YM)             500 non-null    int64
#  2   시간대구간(TIME)          500 non-null    int64
#  3   고객주소블록코드(BLOCK_CD)   500 non-null    int64
#  4   카드이용금액계(AMT_CORR)    500 non-null    int64
#  5   소액결제건수(MICRO_PYM)    500 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 23.6+ KB

# %%
data3
# Out:
#     가맹점주소광역시도(SIDO) 가맹점주소시군구(SGG) 업종대분류(UPJONG_CLASS1)  기준일자(YMD)  \
# 0                서울           강남구                전자상거래   20201021
# 1                서울           관악구                요식/유흥   20170312
# 2                서울           마포구                   주유   20161205
# 3                서울           동작구                   의료   20201210
# 4                서울           NaN             가정생활/서비스   20210216
# ..              ...           ...                  ...        ...
# 495              서울           종로구                가전/가구   20201108
# 496              부산           부평구                   의료   20180901
# 497              서울           강남구                   유통   20160326
# 498              서울           서초구            스포츠/문화/레저   20160804
# 499              인천           마포구                음/식료품   20210628
#
#      고객주소집계구별(TOT_REG_CD)  카드이용금액계(AMT_CORR)  카드이용건수계(USECT_CORR)
# 0           1123077020119             251500                   25
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   가맹점주소광역시도(SIDO)       500 non-null    object
#  1   가맹점주소시군구(SGG)         442 non-null    object
#  2   업종대분류(UPJONG_CLASS1)  500 non-null    object
#  3   기준일자(YMD)             500 non-null    int64
#  4   고객주소집계구별(TOT_REG_CD)  500 non-null    int64
#  5   카드이용금액계(AMT_CORR)     500 non-null    int64
#  6   카드이용건수계(USECT_CORR)   500 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 27.5+ KB

# %%
data4
# Out:
#     업종대분류(UPJONG_CLASS1)  기준일자(YMD)  시간대구간(TIME)  고객주소집계구별(TOT_REG_CD)  \
# 0                  요식/유흥   20161004            6         1123076010009
# 1                     유통   20210303            5         1122060030003
# 2                     유통   20170606            6         1123066022301
# 3              스포츠/문화/레저   20171206            5         1124075020103
# 4                     의료   20160909            6         1113075030002
# ..                   ...        ...          ...                   ...
# 495                전자상거래   20170727            2         1120069010006
# 496                   유통   20190406            3         1123072010303
# 497                교육/학원   20210107            3         1119072030101
# 498                전자상거래   20200426            4         1105063030203
# 499                여행/교통   20160625            4         1103072030001
#
#      카드이용금액계(AMT_CORR)  카드이용건수계(USECT_CORR)
# 0               104624                   10
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   업종대분류(UPJONG_CLASS1)  500 non-null    object
#  1   기준일자(YMD)             500 non-null    int64
#  2   시간대구간(TIME)           500 non-null    int64
#  3   고객주소집계구별(TOT_REG_CD)  500 non-null    int64
#  4   카드이용금액계(AMT_CORR)     500 non-null    int64
#  5   카드이용건수계(USECT_CORR)   500 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 23.6+ KB

# %%
data5
# Out:
#    업종코드(UPJONG_CD) 대분류(CLASS1)  중분류(CLASS2) 소분류(CLASS3)
# 0            ss001       요식/유흥           한식          한식
# 1            ss002       요식/유흥     일식/중식/양식          일식
# 2            ss003       요식/유흥     일식/중식/양식          양식
# 3            ss004       요식/유흥     일식/중식/양식          중식
# 4            ss005       요식/유흥  제과/커피/패스트푸드         제과점
# ..             ...         ...          ...         ...
# 70           ss084   스포츠/문화/레저    스포츠/문화/레저          스키
# 71           ss090       교육/학원           학원      입시보습학원
# 72           ss091       교육/학원           학원       외국어학원
# 73           ss092       교육/학원           학원       예체능학원
# 74           ss093       교육/학원           학원     취미/전문학원
#
# [75 rows x 4 columns]

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   업종코드(UPJONG_CD)  75 non-null     object
#  1   대분류(CLASS1)      75 non-null     object
#  2   중분류(CLASS2)      75 non-null     object
#  3   소분류(CLASS3)      75 non-null     object
# dtypes: object(4)
# memory usage: 2.5+ KB

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## rename

# %%
data1.rename(columns = {'서울시민업종코드(UPJONG_CD)' : 'upjong_cd',
                        '기준년월(YM)':'ym',
                        '고객주소블록코드(BLOCK_CD)':'block_cd',
                        '성별(GEDNER)':'gender',
                        '연령대별(AGE)':'age',
                        '카드이용금액계(AMT_CORR)':'amt_corr',
                        '카드이용건수계(USECT_CORR)':'usect_corr'
                        }, inplace = True)
data2.rename(columns = {'서울시민업종코드(UPJONG_CD)' : 'upjong_cd',
                        '기준년월(YM)':'ym',
                        '시간대구간(TIME)':'time',
                        '고객주소블록코드(BLOCK_CD)':'block_cd',
                        '카드이용금액계(AMT_CORR)':'amt_corr',
                        '소액결제건수(MICRO_PYM)':'micro_pym'
                        }, inplace = True)
data3.rename(columns={'가맹점주소광역시도(SIDO)':'sido',
                      '가맹점주소시군구(SGG)':'sgg',
                      '업종대분류(UPJONG_CLASS1)':'upjong_class1',
                      '기준일자(YMD)':'ymd',
                      '고객주소집계구별(TOT_REG_CD)':'tot_reg_cd',
                      '카드이용금액계(AMT_CORR)':'amt_corr',
                      '카드이용건수계(USECT_CORR)':'usect_corr'}, inplace = True)
data4.rename(columns = {'업종대분류(UPJONG_CLASS1)' : 'upjong_class1',
                        '기준일자(YMD)':'ymd',
                        '시간대구간(TIME)':'time',
                        '고객주소집계구별(TOT_REG_CD)':'tot_reg_cd',
                        '카드이용금액계(AMT_CORR)':'amt_corr',
                        '카드이용건수계(USECT_CORR)':'usect_corr'
                        }, inplace = True)
data5.rename(columns={'업종코드(UPJONG_CD)' :'upjong_cd',
                      '대분류(CLASS1)' : 'class1',
                      '중분류(CLASS2)' : 'class2',
                      '소분류(CLASS3)' : 'class3'}, inplace = True)
data5['upjong_cd']=data5['upjong_cd'].str.upper()

# %% [markdown]
# ## 필요없는 변수 제거

# %%
#df의 block_cd의 의미를 파악해보려했습니다. 고유코드로 이용이 될까 싶어서 파헤쳐보니 같은 block_cd 를 가진 사람이 있었습니다.
#즉 같은 고유코드를 가진 사람은 같은 주소의 사람 (가족) 으로 추측하였습니다.
# 카드소비내역을 설명해주기엔 다소 모호한 부분이 있어서 제외하였습니다.
temp = pd.DataFrame(data1.groupby('block_cd')['gender'].value_counts())
temp.rename(columns = {'gender' : 'count'}, inplace=True)
display(temp.query('count == 2'))
display(temp.query("block_cd == 152747"))
# Out:
#                  count
# block_cd gender
# 152747   M           2
#                  count
# block_cd gender
# 152747   M           2

# %%
data1.drop(['block_cd'], axis=1, inplace=True)
data2.drop(['block_cd'], axis=1, inplace=True)

# %% [markdown]
# ## 업종코드 merge

# %%
data15=pd.merge(data1, data5, left_on='upjong_cd', right_on='upjong_cd',how='inner')

# %%
data25=pd.merge(data2, data5, left_on='upjong_cd', right_on='upjong_cd', how='inner')

# %% [markdown]
# ## 시군구 코드

# %%
sgis = pd.read_excel('datasets/adm_code_new.xlsx')
sgis.drop(['읍면동코드','읍면동명칭','시도코드'], axis=1, inplace=True)
sgis.drop(sgis[sgis['시도명칭']!='서울특별시'].index, axis=0, inplace=True)

# %%
len(sgis['시군구명칭'].unique())
# Out:
# 25

# %% [markdown]
# # 시각화
# ## 1. 성별/연령별

# %% [markdown]
# ### 연령에 따른 카드이용건수계와 이용금액합계

# %%
import plotly.express as px
fig = px.pie(data1, values='usect_corr', names='gender', 
             color='gender',
             color_discrete_map={'M':'#A9BDD8',
                                 'F':'#EF9EB9'},
             width=400, height=400)
fig.update_layout(
    title=dict(
        text='성별 카드이용건수',
        x=0.5, 
        y=0.95,
         font=dict(
            family="Arial",
            size=25,
            color="#000000"
        )
    ),
    font=dict(size=18)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

df1= data1

# N = 100
# random_x = np.linspace(0, 1, N)
# random_y0 = np.random.randn(N) + 5
# random_y1 = np.random.randn(N)
# random_y2 = np.random.randn(N) - 5

x = df1.groupby(by='age').sum().index
y1 = data1[data1['gender'] == 'M'].groupby(by='age').sum()['usect_corr']
y2 = data1[data1['gender'] == 'F'].groupby(by='age').sum()['usect_corr']


# Create traces
fig = go.Figure()
# fig.title('성별 연령별 카드이용건수')
fig.add_trace(go.Scatter(x=x, y=y1,
                    mode='lines',
                    name='M'))
fig.add_trace(go.Scatter(x=x, y=y2,
                    mode='lines',
                    name='F'))

fig.update_layout(
    title=dict(
        text='<b>성별 연령별 카드이용건수</b>',
        x=0.5,
        y=0.87,
        font=dict(
            family="Arial",
            size=25,
            color="#000000"
        )
    ),
    font = dict(
        size=20
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.pie(data1, values='amt_corr', names='gender',
             color='gender',
             color_discrete_map={'M':'#A9BDD8',
                                 'F':'#EF9EB9'},
             width=400, height=400)
fig.update_layout(
    title=dict(
        text='성별 카드이용금액',
        x=0.5, 
        y=0.95,
        font=dict(
            family="Arial",
            size=20,
            color="#000000"
        )
    ),
    font=dict(size=18)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

df1= data1

x = df1.groupby(by='age').sum().index
y1 = data1[data1['gender'] == 'M'].groupby(by='age').sum()['amt_corr']
y2 = data1[data1['gender'] == 'F'].groupby(by='age').sum()['amt_corr']


# Create traces
fig = go.Figure()
# fig.title('성별 연령별 카드이용금액계')
fig.add_trace(go.Scatter(x=x, y=y1,
                    mode='lines',
                    name='M'))
fig.add_trace(go.Scatter(x=x, y=y2,
                    mode='lines',
                    name='F'))
fig.update_layout(
    title=dict(
        text='<b>성별 연령별 카드이용금액계</b>',
        x=0.5,
        y=0.87,
        font=dict(
            family="Arial",
            size=25,
            color="#000000"
        )
    ),
    font = dict(
        size=20
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 2. 시간대별

# %%
fig=px.line(data2,
            x=data2.groupby(by='time').sum().index,
            y=data2.groupby(by='time').sum()['amt_corr'],width=600, height=400)

fig.update_layout(
    title=dict(
        text='시간대별 카드이용금액',
        x=0.5, 
        y=0.95
    ),
    font=dict(size=18)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.line(data2,
            x=data2.groupby(by='time').sum().index,
            y=data2.groupby(by='time').sum()['micro_pym'],width=600, height=400)

fig.update_layout(
    title=dict(
        text='시간대별 소액결제금액',
        x=0.5, 
        y=0.95,
    ),
    font=dict(size=18)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data25_group=data25.groupby('class1')['micro_pym'].sum().reset_index().sort_values(by='micro_pym', ascending=False).head(5)
data_list=data25_group['class1'].tolist()
data_list
# Out:
# ['요식/유흥', '유통', '스포츠/문화/레저', '교육/학원', '음/식료품']

# %%
fig = go.Figure()
x =data25.groupby(by='time').sum().index
for i in data_list:
    y = data25[data25['class1']==i].groupby(by='time').sum()['micro_pym']
    fig.add_trace(go.Scatter(x=x, y=y,
                            mode='lines',
                            name=i))
    
fig.update_xaxes(
    type='category'
)

fig.update_layout(
    title=dict(
        text='<b>시간대별 소액결제금액 top5 상품</b>',
        x=0.5,
        y=0.87
    ),
    xaxis_title=dict(
        text="시간대"
    ),
    yaxis_title="소액결제금액",
    font=dict(
        size=18,
    ),
    showlegend=True,
    margin = dict(l=10, r=10, b=10)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 3. 연도 월별

# %%
from datetime import datetime

data3['ymd'] = pd.to_datetime(data3['ymd'], format='%Y%m%d')

data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sido           500 non-null    object
#  1   sgg            442 non-null    object
#  2   upjong_class1  500 non-null    object
#  3   ymd            500 non-null    datetime64[ns]
#  4   tot_reg_cd     500 non-null    int64
#  5   amt_corr       500 non-null    int64
#  6   usect_corr     500 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 27.5+ KB

# %%
data3_ym = data3
data3_ym['year'] = data3_ym['ymd'].dt.year
data3_ym['month'] = data3_ym['ymd'].dt.month

data3_ym_0 = data3_ym.groupby(['year', 'month']).usect_corr.sum().reset_index()
data3_ym_1 = data3_ym.groupby(['year', 'month']).amt_corr.sum().reset_index()

# %%
import plotly.graph_objects as go

df1= data3_ym_0

x = data3_ym_0.month.unique()

# Create traces
fig = go.Figure()
# fig.title('연도별 월 이용건수 추이')
for i in df1.year.unique():
    y = df1[df1['year'] == i].groupby(by='month').sum()['usect_corr']
    fig.add_trace(go.Scatter(x=x, y=y,
                    mode='lines',
                    name=str(i)+'년'))
# x축 옵션 추가
fig.update_xaxes(
    type='category'
)

fig.update_layout(
    title=dict(
        # <br> 태크와 <sup>태그 사용해서 서브 타이틀을 작성할 수 있음
        text='<b>연도별 월 이용건수 추이</b>',
        x=0.5,
        y=0.87,
        font=dict(
            family="Arial",
            size=25,
            color="#000000"
        )
    ),
    xaxis_title=dict(
        text="월"
    ),
    yaxis_title="이용건수",
    font=dict(
        size=20,
    ),
    showlegend=True,
    margin = dict(l=10, r=10, b=10)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

df1= data3_ym_1

x = data3_ym_1.month.unique()

# Create traces
fig = go.Figure()
# fig.title('연도별 월 이용건수 추이')
for i in df1.year.unique():
    y = df1[df1['year'] == i].groupby(by='month').sum()['amt_corr']
    fig.add_trace(go.Scatter(x=x, y=y,
                    mode='lines',
                    name=str(i)+'년'))
# x축 옵션 추가
fig.update_xaxes(
    type='category'
)

fig.update_layout(
    title=dict(
        # <br> 태크와 <sup>태그 사용해서 서브 타이틀을 작성할 수 있음
        text='<b>연도별 월 이용금액 추이</b>',
        x=0.5,
        y=0.87,
        font=dict(
            family="Arial",
            size=25,
            color="#000000"
        )
    ),
    xaxis_title=dict(
        text="월"
    ),
    yaxis_title="이용건수",
    font=dict(        
        size=20,
        ),
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 4. 상품별

# %%
x = data25.groupby(by='class1').sum().index
y = data25.groupby(by='class1').sum()['amt_corr']

fig = px.bar(x=x, y=y)
fig.update_layout(
    title={
        'text': "업종별 카드이용금액계",
        'y':0.95,
        'x':0.5,
    })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = data25.groupby(by='class1').sum().index
y = data25.groupby(by='class1').sum()['micro_pym']

fig = px.bar(x=x, y=y)
fig.update_layout(
    title={
        'text': "업종별 소액결제건수",
        'y':0.95,
        'x':0.5,
    })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 5. 업종별 성별

# %%
data1_class1_gender=pd.DataFrame(data15.groupby(['class1', 'gender'])['amt_corr','usect_corr'].sum()).reset_index()
data1_class1_gender.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#      class1 gender  amt_corr  usect_corr
# 0     가전/가구      F   1422534          90
# 1     가전/가구      M   1908131         453
# 2  가정생활/서비스      F   4375210         455
# 3  가정생활/서비스      M  11640578         884
# 4     교육/학원      F   2653325         141

# %%
data1_class1_m=data1_class1_gender[data1_class1_gender['gender']=='M']
data1_class1_m
data1_class1_f=data1_class1_gender[data1_class1_gender['gender']=='F']
data1_class1_f
# Out:
#        class1 gender  amt_corr  usect_corr
# 0       가전/가구      F   1422534          90
# 2    가정생활/서비스      F   4375210         455
# 4       교육/학원      F   2653325         141
# 6          미용      F   2705989         176
# 8   스포츠/문화/레저      F   9276125        1000
# 10      여행/교통      F  12589236         487
# 12      요식/유흥      F  46570995        1810
# 14         유통      F  34045859        1958
# 16      음/식료품      F   6792311        1050
# 18         의료      F  15924025        1023
# 20      의류/잡화      F   3032788         165
# 22        자동차      F     66145         850
# 24      전자상거래      F   6102059         618
# 26         주유      F  10448216         256

# %%
import plotly.graph_objects as go
fig=go.Figure(data=[
    go.Bar(x=data1_class1_m['class1'], y=data1_class1_m['usect_corr'], name='Male', marker_color='#A9BDD8'),
    go.Bar(x=data1_class1_f['class1'], y=data1_class1_f['usect_corr'], name='Female', marker_color='#EF9EB9')
])
fig.update_layout(
    title=dict(
        text='업종별 성별 카드이용건수',
        x=0.5, 
        y=0.87
    ),
    font=dict(size=14)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
fig=go.Figure(data=[
    go.Bar(x=data1_class1_m['class1'], y=data1_class1_m['amt_corr'], name='Male', marker_color='#A9BDD8'),
    go.Bar(x=data1_class1_f['class1'], y=data1_class1_f['amt_corr'], name='Female', marker_color='#EF9EB9')
])
fig.update_layout(
    title=dict(
        text='업종별 성별 카드이용금액',
        x=0.5, 
        y=0.87
    ),
    font=dict(size=14)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 6. 지역별

# %%
# seoul data 생성
seoul = data3.drop(index= data3[data3['sido'] != '서울'].index)

# %%
# seoul data 확인
display(seoul.info())
display(seoul.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362 entries, 0 to 498
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sido           362 non-null    object
#  1   sgg            321 non-null    object
#  2   upjong_class1  362 non-null    object
#  3   ymd            362 non-null    datetime64[ns]
#  4   tot_reg_cd     362 non-null    int64
#  5   amt_corr       362 non-null    int64
#  6   usect_corr     362 non-null    int64
#  7   year           362 non-null    int64
#  8   month          362 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 28.3+ KB
# None
#   sido  sgg upjong_class1        ymd     tot_reg_cd  amt_corr  usect_corr  \
# 0   서울  강남구         전자상거래 2020-10-21  1123077020119    251500          25
# 1   서울  관악구         요식/유흥 2017-03-12  1112052010107    158445          20
# 2   서울  마포구            주유 2016-12-05  1113068050004      8048          15
# ...

# %%
# 결측치 제거
seoul = seoul.dropna(axis=0)

# %%
# 서울 시군구(sgg) 확인
seoul['sgg'].unique()
# Out:
# array(['강남구', '관악구', '마포구', '동작구', '중구', '송파구', '용산구', '성북구', '노원구',
#        '서초구', '중랑구', '화성시', '용인시', '남양주시', '종로구', '가평군', '서대문구', '부천시',
#        '양천구', '파주시', '영등포구', '수원시', '광주시', '은평구', '시흥시', '동대문구', '강동구',
#        '안산시', '구로구', '고양시', '성남시', '김포시', '평택시', '성동구', '강북구', '이천시',
#        '의정부시', '양주시', '강서구', '광진구', '금천구', '도봉구', '부평구', '안양시', '하남시',
#        '양평군', '구리시'], dtype=object)

# %%
# 서울 이외의 시군구(sgg) 값 변경
seoul.loc[seoul['sgg'] == '화성시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '용인시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '남양주시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '부천시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '파주시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '수원시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '광주시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '시흥시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '안산시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '고양시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '성남시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '김포시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '평택시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '이천시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '의정부시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '양주시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '안양시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '하남시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '구리시', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '가평군', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '양평군', 'sido'] = '경기'
seoul.loc[seoul['sgg'] == '부평구', 'sido'] = '인천'

seoul = seoul[(seoul['sido'] == '서울')]

# %%
# 시군구(sgg) 기준으로 데이터 생성
seoul2 = seoul.groupby('sgg').sum()
seoul2.reset_index(drop=False, inplace=True)
seoul2 = seoul2[['sgg', 'amt_corr', 'usect_corr']]
seoul2
# Out:
#      sgg  amt_corr  usect_corr
# 0    강남구  11062731         270
# 1    강동구    486904          35
# 2    강북구    291740          10
# 3    강서구    658930          60
# 4    관악구   1477814         201
# 5    광진구    613157          65
# 6    구로구   1043826          65
# 7    금천구    327362          15
# 8    노원구    530162          45
# 9    도봉구    307836          10
# 10  동대문구     12575           5
# 11   동작구   1816182         120
# 12   마포구   8742290         480
# 13  서대문구   3790237         175
# 14   서초구   2511832         216
# 15   성동구   1780218         176
# 16   성북구   2641414         130
# 17   송파구   3336450         145
# 18   양천구   1303203          85
# 19  영등포구   3091428         256
# 20   용산구   5518062         260
# 21   은평구   5292214          20
# 22   종로구    813401          85
# 23    중구   6929651         245
# 24   중랑구   1522028         201

# %%
pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium
from folium.features import DivIcon
import requests
import json

# 서울 행정구역 json
seoul_geo ='datasets/seoul_geo.geojson'
seoul_geo2 = json.load(open(seoul_geo, encoding='utf-8'))

# %%
# 위도경도 매핑
locs = {
    '마포구':(37.55931349, 126.90827),
    '서대문구':(37.57778531, 126.9220631),
    '은평구':(37.62921128, 126.9170229),
    '노원구': (37.65351105, 127.0650347),
    '도봉구':(37.66910208, 127.0223688),
    '강북구':(37.64347391, 127.000000),
    '성북구':(37.6057019, 127.0175795), 
    '중랑구':(37.59980259, 127.0878803),
    '동대문구':(37.58195655, 127.0398481),
    '광진구':(37.54670608, 127.0757435),
    '성동구':(37.55102969, 127.0310585),
    '용산구':(37.53338497, 126.969907),
    '중구': (37.56514356, 126.9979681),
    '종로구':(37.58491732, 126.9773213),
    '강동구':(37.56045024, 127.1470118),
    '송파구':(37.50561924, 127.115295),
    '강남구':(37.49664389, 127.0629852),
    '서초구':(37.47329547, 127.0212203),
    '관악구':(37.46737569, 126.9403372),
    '동작구':(37.50887688, 126.9376415), 
    '영등포구':(37.53230829, 126.9001695),
    '금천구':(37.45516756, 126.9008202),
    '구로구':(37.49940543, 126.8473006),
    '강서구':(37.56123543, 126.832807),
    '양천구':(37.52478941, 126.8454777),
}

locs
# Out:
# {'마포구': (37.55931349, 126.90827),
#  '서대문구': (37.57778531, 126.9220631),
#  '은평구': (37.62921128, 126.9170229),
#  '노원구': (37.65351105, 127.0650347),
#  '도봉구': (37.66910208, 127.0223688),
#  '강북구': (37.64347391, 127.0),
#  '성북구': (37.6057019, 127.0175795),
#  '중랑구': (37.59980259, 127.0878803),
#  '동대문구': (37.58195655, 127.0398481),
#  '광진구': (37.54670608, 127.0757435),
#  '성동구': (37.55102969, 127.0310585),
#  '용산구': (37.53338497, 126.969907),
#  '중구': (37.56514356, 126.9979681),
#  '종로구': (37.58491732, 126.9773213),
#  '강동구': (37.56045024, 127.1470118),
#  '송파구': (37.50561924, 127.115295),
#  '강남구': (37.49664389, 127.0629852),
#  '서초구': (37.47329547, 127.0212203),
#  '관악구': (37.46737569, 126.9403372),
#  '동작구': (37.50887688, 126.9376415),
#  '영등포구': (37.53230829, 126.9001695),
#  '금천구': (37.45516756, 126.9008202),
#  '구로구': (37.49940543, 126.8473006),
#  '강서구': (37.56123543, 126.832807),
#  '양천구': (37.52478941, 126.8454777)}

# %% [markdown]
# > 카드이용건수

# %%
# 서울시 중심부의 위도, 경도 설정
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m 생성
m = folium.Map(location=center, 
               zoom_start=11,
               tiles='cartodbpositron')

# Choropleth 레이어를 만들고, 맵 m에 추가
folium.Choropleth(
    geo_data=seoul_geo,
    data=seoul2,
    columns=('sgg', 'usect_corr'),
    key_on='feature.properties.SGG_NM',
    fill_color='YlGn',
    legend_name='이용 건수',
).add_to(m)

# map위에 text 추가
for key, value in locs.items():
  folium.map.Marker(
      [value[0], value[1]-0.005],
      icon=DivIcon(
          icon_size=(0, 0),
          icon_anchor=(0, 0),

          html='<div\
          style="\
          font-size:1.4rem;\
          color:black;\
          width:85px;\
          text-align:left;\
          margin:0px;\
          "><b>'
          + key
          +'</b></div>'
      )).add_to(m)

# 맵 m 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# > 카드이용금액

# %%
# 서울시 중심부의 위도, 경도
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m 생성
m = folium.Map(location=center, 
               zoom_start=11,
               tiles='cartodbpositron')

# Choropleth 레이어를 만들고, 맵 m에 추가
folium.Choropleth(
    geo_data=seoul_geo,
    data=seoul2,
    columns=('sgg', 'amt_corr'),
    key_on='feature.properties.SGG_NM',
    fill_color='YlGn',
    legend_name='이용 금액',
).add_to(m)

# map위에 text 추가
for key, value in locs.items():
  folium.map.Marker(
      [value[0], value[1]-0.005],
      icon=DivIcon(
          icon_size=(0, 0),
          icon_anchor=(0, 0),

          html='<div\
          style="\
          font-size:1.4rem;\
          color:black;\
          width:85px;\
          text-align:left;\
          margin:0px;\
          "><b>'
          + key
          +'</b></div>'
      )).add_to(m)


# 맵 m 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
